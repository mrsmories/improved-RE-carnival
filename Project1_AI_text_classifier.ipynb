# %% [markdown]
# <a href="https://colab.research.google.com/github/mrsmories/improved-RE-carnival/blob/main/Project1_AI_text_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# %%
data = {
'review': [
"i love this movie"
,
"horrible acting"
,
"a great film"
,
"worst movie ever"
,
"really enjoyed it"
,
"it was terrible"
,
"fantastic performance"
,
"not good at all"
,
"boring"
,
"very emotional"
,
"made me happy"
,
"so funny"
,
"loved it"
,
"makes me happy"
,
"light hearted"
,
"very dumb"
,
"my girlfriend hated it", "the rock was terrible", "great action",
"i want to see it again", "we hated it", "so stupid"

],
'label': ['positive'
,
'negative'
,
'positive'
,
'negative'
,
'positive'
,
'negative'
,
'positive'
,
'negative'
,
'negative'
,
'positive'
,
'positive'
,
'positive'
,
'positive'
,
'positive'
,
'positive'
,
'negative'
,
'negative', 'negative', 'positive', 'positive', 'negative', 'negative']
}
df = pd.DataFrame(data)

# %% [markdown]
# Convert Text to Numeric Format
# Count Vectorizer converts text into bag of words and counts frequency of each word

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(df['review'])
y = df['label']

# %% [markdown]
# Split the Data for Training and Testing

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %% [markdown]
# Train the Model
# Naive Bayes:  P(Class|Data) =
# (P(Data|Class) * P(Class))/P(Data)
# NB Multinomial counts data (like word count in text)

# %%
model = MultinomialNB()
model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %% [markdown]
# Evaluate the Model

# %%
y_pred = model.predict(X_test)
print("Accuracy:"
, accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8

# %% [markdown]
# Test Your Own Review

# %%
your_review = ["i hated the plot"]
your_review_vector = vectorizer.transform(your_review)
print("Prediction:"
, model.predict(your_review_vector))
# Out:
# Prediction: ['negative']

# %%
your_review = ["it was dumb"]
your_review_vector = vectorizer.transform(your_review)
print("Prediction:"
, model.predict(your_review_vector))
# Out:
# Prediction: ['negative']

# %%
your_review = ["characters were stupid"]
your_review_vector = vectorizer.transform(your_review)
print("Prediction:"
, model.predict(your_review_vector))
# Out:
# Prediction: ['negative']

# %%
your_review = ["i cry so hard"]
your_review_vector = vectorizer.transform(your_review)
print("Prediction:"
, model.predict(your_review_vector))
# Out:
# Prediction: ['positive']

# %%
your_review = ["best action"]
your_review_vector = vectorizer.transform(your_review)
print("Prediction:"
, model.predict(your_review_vector))
# Out:
# Prediction: ['positive']

# %%
your_review = ["very funny"]
your_review_vector = vectorizer.transform(your_review)
print("Prediction:"
, model.predict(your_review_vector))
# Out:
# Prediction: ['positive']
